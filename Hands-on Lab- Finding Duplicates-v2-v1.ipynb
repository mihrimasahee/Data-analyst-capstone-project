# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Finding Duplicates Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Introduction

# %% [markdown]
# Data wrangling is a critical step in preparing datasets for analysis, and handling duplicates plays a key role in ensuring data accuracy. In this lab, you will focus on identifying and removing duplicate entries from your dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab, you will perform the following:

# %% [markdown]
# 1. Identify duplicate rows in the dataset and analyze their characteristics.
# 2. Visualize the distribution of duplicates based on key attributes.
# 3. Remove duplicate values strategically based on specific criteria.
# 4. Outline the process of verifying and documenting duplicate removal.

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Install the needed library

# %%
# !pip install pandas
# !pip install matplotlib

# %% [markdown]
# Import pandas module

# %%
import pandas as pd

# %% [markdown]
# Import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Load the dataset into a dataframe**

# %% [markdown]
# <h2>Read Data</h2>
# <p>
# We utilize the <code>pandas.read_csv()</code> function for reading CSV files. However, in this version of the lab, which operates on JupyterLite, the dataset needs to be downloaded to the interface using the provided code below.
# </p>

# %%
# Load the dataset directly from the URL
file_path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/VYPrOu0Vs3I0hKLLjiPGrA/survey-data-with-duplicate.csv"
df = pd.read_csv(file_path)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# Load the data into a pandas dataframe:

# %% [markdown]
# Note: If you are working on a local Jupyter environment, you can use the URL directly in the pandas.read_csv() function as shown below:

# %%
# df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv")

# %% [markdown]
# ## Identify and Analyze Duplicates

# %% [markdown]
# ### Task 1: Identify Duplicate Rows
# 1. Count the number of duplicate rows in the dataset.
# 3. Display the first few duplicate rows to understand their structure.

# %%
## Write your code here
df.duplicated().sum()
duplicates=df[df.duplicated(keep=False)]
duplicates.head()
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# ...

# %% [markdown]
# ### Task 2: Analyze Characteristics of Duplicates
# 1. Identify duplicate rows based on selected columns such as MainBranch, Employment, and RemoteWork. Analyse which columns frequently contain identical values within these duplicate rows.
# 2. Analyse the characteristics of rows that are duplicates based on a subset of columns, such as MainBranch, Employment, and RemoteWork. Determine which columns frequently have identical values across these rows.

# %%
subset_cols = ['MainBranch', 'Employment', 'RemoteWork']
duplicates_subset = df[df.duplicated(subset=subset_cols, keep=False)]
grouped = duplicates_subset.groupby(subset_cols)
def identical_column_counts(group):
    # For each column, check if all values are the same
    return (group.nunique(dropna=False) == 1).sum()

# Apply to each group and calculate average number of identical columns
identical_counts = grouped.apply(identical_column_counts,include_groups=False)
print(f"\nAverage number of identical columns among duplicate groups: {identical_counts.mean():.2f}")

# Step 5: Determine which columns most often have identical values
def identical_columns(group):
    return (group.nunique(dropna=False) == 1)

column_similarity = grouped.apply(identical_columns,include_groups=False).mean()
column_similarity = column_similarity.sort_values(ascending=False)

print("\nColumns with most consistent values among duplicate groups:")
display(column_similarity)
# Out:
# Average number of identical columns among duplicate groups: 24.13
#
# Columns with most consistent values among duplicate groups:
# Check                         1.000000
# AINextMuch less integrated    0.667712
# ConvertedCompYearly           0.517241
# AINextLess integrated         0.504702
# BuildvsBuy                    0.504702
#                                 ...
# LanguageHaveWorkedWith        0.012539
# YearsCode                     0.012539
# LearnCode                     0.012539
# CodingActivities              0.003135
# ResponseId                    0.000000
# Length: 111, dtype: float64

# %% [markdown]
# ### Task 3: Visualize Duplicates Distribution
# 1. Create visualizations to show the distribution of duplicates across different categories.
# 2. Use bar charts or pie charts to represent the distribution of duplicates by Country and Employment.

# %%
## Write your code here
import seaborn as sns
fig = plt.figure(figsize=(15, 6))
#plt.add_subplot()
country_counts = duplicates['Country'].value_counts().head(10)
#plt.figure(figsize=(10, 6))
sns.barplot(x=country_counts.values, y=country_counts.index)
plt.title("Top 10 Countries with Most Duplicates")
plt.xlabel("Number of Duplicate Rows")
plt.ylabel("Country")
plt.tight_layout()
plt.show()

Employment = duplicates['Employment'].value_counts()
#plt.figure(figsize=(10, 6))
Employment.plot(kind='pie',
                                figsize=(15, 6),
                                autopct='%1.1f%%', 
                                startangle=90,    
                                #shadow=True,       
                                labels=None,                 
                                pctdistance=1.12)         
                                      
plt.legend(labels=Employment.index, loc='upper right') 
#plt.pie(Employment, labels=Employment.index, autopct='%1.1f%%', startangle=140)
plt.title("Employement with Most Duplicates")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Strategic Removal of Duplicates
# 1. Decide which columns are critical for defining uniqueness in the dataset.
# 2. Remove duplicates based on a subset of columns if complete row duplication is not a good criterion.

# %%
## Write your code here
key_columns = ['MainBranch', 'Employment', 'RemoteWork', 'Country', 'YearsCode']
# Drop duplicates using only key identifying columns
df_unique = df.drop_duplicates(subset=key_columns, keep='first')

print(f"Original dataset rows: {len(df)}")
print(f"Rows after removing duplicates: {len(df_unique)}")
print(f"Number of rows removed: {len(df) - len(df_unique)}")
# Out:
# Original dataset rows: 65457
# Rows after removing duplicates: 23524
# Number of rows removed: 41933

# %%
# Check how many duplicates each country lost

before = df['Country'].value_counts()
after = df_unique['Country'].value_counts()
lost = (before - after).dropna()

print("\nCountries with most rows removed (likely duplicates):")
print(lost[lost > 0].sort_values(ascending=False).head(10))
# Out:
# Countries with most rows removed (likely duplicates):
# Country
# United States of America                                9207
# Germany                                                 3760
# India                                                   3335
# United Kingdom of Great Britain and Northern Ireland    2384
# Ukraine                                                 2007
# France                                                  1471
# Canada                                                  1356
# Poland                                                   930
# Netherlands                                              885
# Brazil                                                   819
# Name: count, dtype: int64

# %% [markdown]
# ## Verify and Document Duplicate Removal Process

# %% [markdown]
# ### Task 5: Documentation
# 1. Document the process of identifying and removing duplicates.

# %%
dupes = df[df.duplicated(keep=False)]
pd.set_option('display.max_columns', None)  # show all columns
dupes.sort_values(by=list(df.columns)).head(10)
# Out:
#        ResponseId                      MainBranch                 Age  \
# 0               1  I am a developer by profession  Under 18 years old
# 65437           1  I am a developer by profession  Under 18 years old
# 1               2  I am a developer by profession     35-44 years old
# 65438           2  I am a developer by profession     35-44 years old
# 2               3  I am a developer by profession     45-54 years old
# 65439           3  I am a developer by profession     45-54 years old
# 3               4           I am learning to code     18-24 years old
# 65440           4           I am learning to code     18-24 years old
# 4               5  I am a developer by profession     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 0      Employed, full-time     Remote  Apples
# 65437  Employed, full-time     Remote  Apples
# 1      Employed, full-time     Remote  Apples
# ...

# %%
# Write your explanation here
duplicate_rows = df[df.duplicated()]
print("Duplicate rows:", len(duplicate_rows))
duplicate_rows.head()
# Out:
# Duplicate rows: 20
#        ResponseId                      MainBranch                 Age  \
# 65437           1  I am a developer by profession  Under 18 years old
# 65438           2  I am a developer by profession     35-44 years old
# 65439           3  I am a developer by profession     45-54 years old
# 65440           4           I am learning to code     18-24 years old
# 65441           5  I am a developer by profession     18-24 years old
#
#                 Employment RemoteWork   Check  \
# 65437  Employed, full-time     Remote  Apples
# 65438  Employed, full-time     Remote  Apples
# 65439  Employed, full-time     Remote  Apples
# 65440   Student, full-time        NaN  Apples
# 65441   Student, full-time        NaN  Apples
#
#                                         CodingActivities  \
# 65437                                              Hobby
# 65438  Hobby;Contribute to open-source projects;Other...
# 65439  Hobby;Contribute to open-source projects;Other...
# ...

# %% [markdown]
# 2. Explain the reasoning behind selecting specific columns for identifying and removing duplicates.

# %% [raw]
# # Write your explanation here
# The reasoning behind selecting specific columns (instead of using all columns) for identifying and removing duplicates comes down to data quality, real-world meaning, and analytical purpose. Here's a breakdown of the reasoning:
#
# 🎯 1. Not All Columns Are Relevant for Uniqueness
# Some columns may vary even when the row represents the same real-world entity. For example:
#
# ResponseId	Country	MainBranch	YearsCode
# 1001	India	Developer	5
# 1002	India	Developer	6
#
# These two responses may represent the same type of participant — country and job role are the same — but their ResponseId and YearsCode differ. If you're analyzing demographics or role-based trends, the difference in YearsCode may not matter.
#
# ✅ So instead of using all columns, we use key identifying columns like:
#
# Country
#
# MainBranch
#
# Employment
#
# RemoteWork
#
# 🤔 2. Some Columns Are Always Unique or Not Useful for De-duplication
# Examples:
#
# ResponseId: Always unique, so including it will make every row look unique — even if the person submitted the same answer twice.
#
# Timestamp: May differ slightly even if rest of the row is identical.
#
# Other text columns: Can include noise or personalized answers that aren’t relevant for deduplication.
#
# 💡 Including these prevents detection of duplicates that actually matter.
#
# 🧠 3. Columns Selected Should Represent Logical Identity
# We select columns that logically define a "unique response". In survey datasets, that often includes:
#
# Employment type
#
# Role (MainBranch)
#
# Remote work status
#
# Country
#
# Experience group
#
# If two rows share these values, it’s likely the same user (or a nearly identical one), even if their age or free-text fields differ slightly.
#
# 🧽 4. Cleaner Deduplication by Subset Helps Preserve Real Variation
# By using subset=['MainBranch', 'Employment', 'RemoteWork'], we:
#
# Detect near-identical entries (likely redundant)
#
# Avoid deleting meaningful rows that differ on purpose (e.g., different programming languages used)
#
# ✅ Summary: When Choosing Columns for Duplicate Removal
#          Criteria	                                     Explanation
# ✅ Stable & representative	            Should define a user or category clearly
# ❌ Unique identifiers	                Will block all duplicates from being detected
# ✅ Frequently repeated in duplicates	Helps catch redundant entries
# ❌ Noisy or free-text fields	        Often introduce minor, irrelevant differences

# %% [markdown]
# ### Summary and Next Steps
# **In this lab, you focused on identifying and analyzing duplicate rows within the dataset.**
#
# - You employed various techniques to explore the nature of duplicates and applied strategic methods for their removal.
# - For additional analysis, consider investigating the impact of duplicates on specific analyses and how their removal affects the results.
# - This version of the lab is more focused on duplicate analysis and handling, providing a structured approach to deal with duplicates in a dataset effectively.

# %% [markdown]
# <!--
# ## Change Log
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2024-11- 05|1.3|Madhusudhan Moole|Updated lab|
# |2024-10-28|1.2|Madhusudhan Moole|Updated lab|
# |2024-09-24|1.1|Madhusudhan Moole|Updated lab|
# |2024-09-23|1.0|Raghul Ramesh|Created lab|
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
